# %% [markdown]
# # Model validation for time series data
#
# #### 🎯 Learning Goals
#
# 1. **Model validation** for time series data
# 2. Proper **data preprocessing** and feature engineering

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import TimeSeriesSplit
from statsmodels.tsa.seasonal import seasonal_decompose
import statsmodels.api as sm

# %% [markdown]
# ## Validation Strategies
#
# ### Time Series specific challenges
#
# Time series data presents unique challenges for model validation due to its chronological nature. The K-Fold cross-validation method should be adjusted for time series because:
#
# + There is a dependency between the training and validation datasets, which can lead to overfitting.
# + The model may be trained with *future* information, leading to unrealistic performance metrics (*data leakage*))
#
# ### Out-of-sample Evaluation (OOS)
#
# OOS evaluation is a widely-used and intuitive approach for time series. It involves selecting testing data that occurs after the training data.
# We explore two methods (apart from just one validation sample):
#
# + the expanding window
# + the sliding/rolling window algorithms
#
# #### Multiple Train-Test Splits
#
# The expanding window validation starts with a fixed base training set. In the first iteration, the model is tested on the initial test set. For each subsequent iteration, the previous test set is added to the training data, and a new test set of the same size is introduced. This process continues until the data is exhausted.
#
# <img src="img/expanding_window_validation.jpg" alt="Expanding Window Validation" width="600"/>
#
# In the rolling or sliding window validation, the training data size remains constant. As the validation progresses, the start point of the training data is moved forward.
#
# <img src="img/rolling_window_validation.jpg" alt="Expanding Window Validation" width="600"/>
#
# The performance evaluation is based on the aggregated loss from the predictions on the test segments.

# %% [markdown]
# ____
# #### ➡️ ✏️ Task 1
#
#
# We want to learn the model for the time series data. In particular, we want to fit an AR(p) model for stationary $\{y_t\}$. We are unsure about $p$ and hence wish to perform model validation. We start with keeping out only one validation set.
#
# + Check model performance for $p \in \{0, 1, 2, 3\}$. Use the first  750 observations for training and the remaining data for validation. For each $p$ repeat the following steps:
#     + Use `sm.tsa.ARIMA` to initialize an appropriate object.
#     + Use `statsmodels.tsa.arima.model.ARIMAResults.forecast` to forecast the values in the validation data.
#     + Record the mean-squared error (MSE) of your forecasts on the validation set.
# + Which model do you select based on the performance on the validation set?

# %%
series1 = pd.read_csv("data/series1.csv")

max_order = 3 # set highest p
n_models = max_order + 1 # add 1 for the AR(0) 

results = pd.DataFrame(np.zeros((0, n_models)))
results.columns = np.arange(0, n_models)
training = series1.iloc[:750]
testing = series1.iloc[750:]

for p in range(0, n_models):
        mod = sm.tsa.ARIMA(training, order=(p, 0, 0))
        res = mod.fit()
        forecast = res.forecast(steps=250, signal_only=False)
        mse = np.mean((testing.values - forecast.values)**2)
        print(mse)
        results.loc[0, p] = mse
results
# Out:
# 2.9299568702554586
# 2.971270900929357
# 2.956747160190016
# 2.957916791774414
#           0         1         2         3
# 0  2.929957  2.971271  2.956747  2.957917

# %% [markdown]
# ____
# #### ➡️ ✏️ Task 2
#
# Redo your analysis above, however, this time using an expanding window and 5 iterations in your validation process.
#
# + Fix the first 750 observations for training and 50 observations to evaluate your model using the expanding window strategy.
# + Expand the window appropriately.
# + Record the mean-squared error (MSE) of your forecasts on the validation sets.
#
# Which model do you select?

# %%
# Your solution

results = pd.DataFrame(np.zeros((1, 10)))
results.columns = np.arange(1, 11)

for iter in range(0, 5):
    lim = 750 + 50*iter
    lim_up = lim + 50
    training = series1[:lim]
    testing = series1[lim:lim_up]
    for p in range(1, 11):
        mod = sm.tsa.ARIMA(training, order=(p, 0, 0))
        res = mod.fit()
        forecast = res.forecast(steps=50, signal_only=False)
        results.loc[0, p] = results.loc[0, p] + ((testing.values - forecast.values)**2).mean()
results = results / 5
display(min(results))
# Out:
# 1

# %% [markdown]
# ____
# #### ➡️ ✏️ Task 3
#
# Redo your analysis, however, this time using a rolling window and 5 iterations in your validation process.
#
# + Fix the first 750 observations for training and the next 50 observations to evaluate your model using the rolling window atrtegy.
# + Shift the window appropriately.
# + Record the mean-squared error (MSE) of your forecasts on the validation sets.
#
# Which model do you select?

# %%
# Your solution

results = pd.DataFrame(np.zeros((1, 10)))
results.columns = np.arange(1, 11)

for iter in range(0, 5):
    start = 50*iter
    lim = 750 + 50*iter
    lim_up = lim + 50
    training = series1[start:lim]
    testing = series1[lim:lim_up]
    for p in range(1, 11):
        mod = sm.tsa.ARIMA(training, order=(p, 0, 0))
        res = mod.fit()
        forecast = res.forecast(steps=50, signal_only=False)
        results.loc[0, p] = results.loc[0, p] + ((testing.values - forecast.values)**2).mean()
results = results / 5
display(results)
display(min(results))
# Out:
#          1         2         3         4         5         6         7   \
# 0  2.947801  2.912059  2.914602  2.911747  2.903073  2.902098  2.902533
#
#          8         9         10
# 0  2.904302  2.904866  2.905075
# 1

# %% [markdown]
# # Model validation for time series data
#
# #### 🎯 Learning Goals
#
# 1. **Model validation** for time series data
# 2. Proper **data preprocessing** and feature engineering

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import TimeSeriesSplit
from statsmodels.tsa.seasonal import seasonal_decompose
import statsmodels.api as sm

# %% [markdown]
# ## Validation Strategies
#
# ### Time Series specific challenges
#
# Time series data presents unique challenges for model validation due to its chronological nature. The K-Fold cross-validation method should be adjusted for time series because:
#
# + There is a dependency between the training and validation datasets, which can lead to overfitting.
# + The model may be trained with *future* information, leading to unrealistic performance metrics (*data leakage*))
#
# ### Out-of-sample Evaluation (OOS)
#
# OOS evaluation is a widely-used and intuitive approach for time series. It involves selecting testing data that occurs after the training data.
# We explore two methods (apart from just one validation sample):
#
# + the expanding window
# + the sliding/rolling window algorithms
#
# #### Multiple Train-Test Splits
#
# The expanding window validation starts with a fixed base training set. In the first iteration, the model is tested on the initial test set. For each subsequent iteration, the previous test set is added to the training data, and a new test set of the same size is introduced. This process continues until the data is exhausted.
#
# <img src="img/expanding_window_validation.jpg" alt="Expanding Window Validation" width="600"/>
#
# In the rolling or sliding window validation, the training data size remains constant. As the validation progresses, the start point of the training data is moved forward.
#
# <img src="img/rolling_window_validation.jpg" alt="Expanding Window Validation" width="600"/>
#
# The performance evaluation is based on the aggregated loss from the predictions on the test segments.

# %% [markdown]
# ____
# #### ➡️ ✏️ Task 1
#
#
# We want to learn the model for the time series data. In particular, we want to fit an AR(p) model for stationary $\{y_t\}$. We are unsure about $p$ and hence wish to perform model validation. We start with keeping out only one validation set.
#
# + Check model performance for $p \in \{0, 1, 2, 3\}$. Use the first  750 observations for training and the remaining data for validation. For each $p$ repeat the following steps:
#     + Use `sm.tsa.ARIMA` to initialize an appropriate object.
#     + Use `statsmodels.tsa.arima.model.ARIMAResults.forecast` to forecast the values in the validation data.
#     + Record the mean-squared error (MSE) of your forecasts on the validation set.
# + Which model do you select based on the performance on the validation set?

# %%
series1 = pd.read_csv("data/series1.csv")

max_order = 3 # set highest p
n_models = max_order + 1 # add 1 for the AR(0) 

results = pd.DataFrame(np.zeros((0, n_models)))
results.columns = np.arange(0, n_models)
training = series1.iloc[:750]
testing = series1.iloc[750:]

for p in range(0, n_models):
        mod = sm.tsa.ARIMA(training, order=(p, 0, 0))
        res = mod.fit()
        forecast = res.forecast(steps=250, signal_only=False)
        mse = np.mean((testing.values - forecast.values)**2)
        print(mse)
        results.loc[0, p] = mse
results
# Out:
# 2.9299568702554586
# 2.971270900929357
# 2.956747160190016
# 2.957916791774414
#           0         1         2         3
# 0  2.929957  2.971271  2.956747  2.957917

# %% [markdown]
# ____
# #### ➡️ ✏️ Task 2
#
# Redo your analysis above, however, this time using an expanding window and 5 iterations in your validation process.
#
# + Fix the first 750 observations for training and 50 observations to evaluate your model using the expanding window strategy.
# + Expand the window appropriately.
# + Record the mean-squared error (MSE) of your forecasts on the validation sets.
#
# Which model do you select?

# %%
# Your solution

results = pd.DataFrame(np.zeros((1, 10)))
results.columns = np.arange(1, 11)

for iter in range(0, 5):
    lim = 750 + 50*iter
    lim_up = lim + 50
    training = series1[:lim]
    testing = series1[lim:lim_up]
    for p in range(1, 11):
        mod = sm.tsa.ARIMA(training, order=(p, 0, 0))
        res = mod.fit()
        forecast = res.forecast(steps=50, signal_only=False)
        results.loc[0, p] = results.loc[0, p] + ((testing.values - forecast.values)**2).mean()
results = results / 5
display(min(results))
# Out:
# 1

# %% [markdown]
# ____
# #### ➡️ ✏️ Task 3
#
# Redo your analysis, however, this time using a rolling window and 5 iterations in your validation process.
#
# + Fix the first 750 observations for training and the next 50 observations to evaluate your model using the rolling window atrtegy.
# + Shift the window appropriately.
# + Record the mean-squared error (MSE) of your forecasts on the validation sets.
#
# Which model do you select?

# %%
# Your solution

results = pd.DataFrame(np.zeros((1, 10)))
results.columns = np.arange(1, 11)

for iter in range(0, 5):
    start = 50*iter
    lim = 750 + 50*iter
    lim_up = lim + 50
    training = series1[start:lim]
    testing = series1[lim:lim_up]
    for p in range(1, 11):
        mod = sm.tsa.ARIMA(training, order=(p, 0, 0))
        res = mod.fit()
        forecast = res.forecast(steps=50, signal_only=False)
        results.loc[0, p] = results.loc[0, p] + ((testing.values - forecast.values)**2).mean()
results = results / 5
display(results)
display(min(results))
# Out:
#          1         2         3         4         5         6         7   \
# 0  2.947801  2.912059  2.914602  2.911747  2.903073  2.902098  2.902533
#
#          8         9         10
# 0  2.904302  2.904866  2.905075
# 1
